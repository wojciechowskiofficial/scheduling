# %%
from scipy.stats import chi2
import numpy as np

# %%
x = np.arange(0, 32, 0.1)
y = chi2.pdf(x, 5, scale=1, loc=5)ghp_u

# %%
plt.plot(x, y)
plt.show()

# %%
chi2.rvs(df=5, scale=2, size=10)
# Out:
# array([11.22628956,  1.91020911,  4.63402302,  7.42479168,  3.53257948,
#        10.64360171, 13.52844946,  2.07104695,  3.33436072,  8.34196138])

# %%
z = chi2.cdf(x, 5)
z[-2]
# Out:
# 0.9925611025034052
